# %% [markdown]
# <a href="https://colab.research.google.com/github/Brutusa/Stock-Market-Prediction-with-Pytorch/blob/main/stockMarketPredictionPytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as func
import torch.optim as optim
import matplotlib.pyplot as plt
import math

# download and import the 'datasets' folder from:
# https://drive.google.com/drive/folders/1Wz4uHMNfXBhkwIvRsaLpYU3PWe_y4HXj?usp=drive_link

# for use in Colab: Place individual files in the hierarchy './datasets/amd_dataset.csv'
# change lines 18 & 19 to the appropriate file names

# Load dataset
# Skip rows = 1 because those are the column names
X = np.array([])
dataset = np.loadtxt('./datasets/adobe_dataset.csv', delimiter=',', skiprows=1, usecols=(1,2,3,4,5))
target_dataset = np.loadtxt('./datasets/adobe_dataset.csv', delimiter=',', skiprows=1, usecols=(7))
# use cols skips over column 6 as that is the symbol of the stock
X = dataset


# feature list
# access a specific feature with data[i, 4] which would be entry i, feature 4
raw_open_price_data = np.array(dataset[:,0:1])
raw_high_data = np.array(dataset[:,0:2])
raw_low_data = np.array(dataset[:,0:3])
raw_close_price_data = np.array(dataset[:,0:4])
raw_volume_data = np.array(dataset[:,0:5])

# target list
y = np.array(target_dataset[:])

# Function to normalize from 0 to 1
def normalize(v, min, max):
  # Min Max Normalization formula
  new_v = ((v - min)*(1-0))/ (100-20) + 0
  return new_v

# Normalize lists
X = normalize(X, np.min(X), np.max(X))
normalized_volume = X[:,0:5]

# convert lists to pytorch lists
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# Define ANN model
class StockPredictionANN(nn.Module):
  # Play with values to see what gives best result
  def __init__(self):
    super(StockPredictionANN, self).__init__()

    self.hidden1 = nn.Linear(5, 7, bias=True)
    self.hidden2 = nn.Linear(7, 7, bias=True)
    self.output = nn.Linear(7, 1, bias=True)


  def forward(self, x):
    x = func.sigmoid(self.hidden1(x))
    x = func.sigmoid(self.hidden2(x))
    x = func.sigmoid(self.output(x))
    return x

# Define Linear Regression model
class StockPredictionLinReg(nn.Module):
    def __init__(self):
      super(StockPredictionLinReg, self).__init__()
      self.linear = nn.Linear(5, 1)

    def forward(self, x):
      x = self.linear(x)
      return x

# Define Logistic Regression model
class StockPredictionLogReg(nn.Module):
    def __init__(self):
        super(StockPredictionLogReg, self).__init__()
        self.linear = nn.Linear(5, 1)

    def forward(self, x):
      x = func.sigmoid(self.linear(x))
      return x

# change model here:
model = StockPredictionANN()
#model = StockPredictionLinReg()
#model = StockPredictionLogReg()

# set learning rate
learning_rate = .001

# loss function
loss_fn = nn.MSELoss()

# Adam is the most popular form of gradient descent
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# for x number of epochs
num_epochs = 50
# make calculations for data in batches of y days at a time
daily = 2
weekly = 7
monthly = 30

batch_size = daily

# list to store predictions
y_predictions = np.array([])


# TRAINING
for i in range(0, 882):#len(X)):
    for epoch in range(num_epochs):
        # Xbatch: process rows i and i+batch_size from the csv
        Xbatch = X[i:i+batch_size]
        # y_pred: make prediction based on current batch
        y_pred = model(Xbatch)
        # ybatch: process rows i and i+batch_size of target outputs from csv
        ybatch = y[i:i+batch_size]
        # compare predicted y with current batch
        loss = loss_fn(y_pred, ybatch)
        # backpropagate
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
#    print(f'epoch: {epoch}, loss: {loss}')

# TESTING
for i in range(0, len(X)): #SET BACK TO 0
    for epoch in range(num_epochs):
        # Xbatch: process rows i and i+batch_size from the csv
        Xbatch = X[i:i+batch_size]
        # y_pred: make prediction based on current batch
        y_pred = model(Xbatch)

        if epoch == num_epochs-1:
          # append to list of predictions
          y_predictions = np.append(y_predictions, y_pred[0,0].item())

        # ybatch: process rows i and i+batch_size of target outputs from csv
        ybatch = y[i:i+batch_size]
        # compare predicted y with current batch
        loss = loss_fn(y_pred, ybatch)
        # backpropagate
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
#    print(f'epoch: {epoch}, loss: {loss}')

# list to store trend data
pred_trend = np.array([])
current_price_prediction = np.array([])
current_price_prediction = np.append(current_price_prediction, raw_open_price_data[0])
opening_value = current_price_prediction[0]

# Function to categorize trend prediction
for i in range(len(y_predictions)):
  # if the prediction for today is greater than yesterday:
  if y_predictions[i] > y_predictions[i-1]:
    # then positive trend
    current_trend = 1
    pred_trend = np.append(pred_trend,1)
  else:
    # else negative trend
    current_trend = 0
    pred_trend = np.append(pred_trend,0)

# Function to calculate price calculation and accuracy
# Make a for loop to take prediction for a given range based on batch size i.e. weekly has batch of 7, so apply this function from the values of i + 0-7 then take average (sum then divide total by size)
for i in range(len(y_predictions)):
  #test = 0
  #test = (sum(raw_open_price_data[i:i+batch_size,0])/batch_size) + sum(raw_close_price_data[i:i+batch_size,0] - raw_open_price_data[i:i+batch_size,0])
  #print("predicted open price for day ", i, " is: ", test)

  # FORMULA 1: (all values * batch_size)/4*batch_size
  #current_price_prediction = np.append(current_price_prediction, (raw_open_price_data[i:i+batch_size,0]+raw_high_data[i:i+batch_size,0]+raw_low_data[i:i+batch_size,0]+raw_close_price_data[i:i+batch_size,0])/(4*batch_size))

  # FORMULA 2: the sum of X adjacent day's worth of open price data divided by the number of days "X" + the sum of the price variance between those adjacent days
  '''
  if pred_trend[i] == 1:
    # increasing price prediction
    current_price_prediction = np.append(current_price_prediction, (sum(raw_open_price_data[i:i+batch_size,0])/batch_size) + sum(raw_close_price_data[(i+1):(i+1)+batch_size,0] - raw_open_price_data[i:i+batch_size,0])/batch_size)
  elif pred_trend[i] == 0:
    # decreasing price prediction
    current_price_prediction = np.append(current_price_prediction, (sum(raw_open_price_data[i:i+batch_size,0])/batch_size) + sum(raw_close_price_data[(i+1):(i+1)+batch_size,0] - raw_open_price_data[i:i+batch_size,0])/batch_size)
'''
  # FORMULA 3:
  # Calculate the average difference between close and open prices for the current batch
  average_difference = np.mean(raw_close_price_data[i+1:i+1+batch_size, 0] - raw_open_price_data[i:i+batch_size, 0])

  # Update the opening_value using the trend data
  if pred_trend[i] == 1:
    opening_value += abs(average_difference)
  elif pred_trend[i] == 0:
    opening_value -= abs(average_difference)

  # Append the updated opening_value to current_price_prediction
  current_price_prediction = np.append(current_price_prediction, opening_value)



def print_results():
  # print results
  for i in range(len(y)):
    print('day %d to %d | predicted trend: %d | target trend: %d | predicted price: $%.2f | actual price: $%.2f' % (i, i+1, pred_trend[i], y[i], current_price_prediction[i], raw_open_price_data[i,0]))
    print('difference from predicted price to actual price: $%.2f ' % (current_price_prediction[i] - raw_open_price_data[i]))

# torch.no_grad() ends pytorch's cpu utilization when calculations are done
with torch.no_grad():
    y_pred = model(X)


# compute accuracy
def get_accuracy():
  num_correct = 0

  for num in range(len(pred_trend)):
    if pred_trend[num] == y[num]:
      num_correct += 1

  accuracy = (num_correct / len(y)) * 100
  print('Accuracy: %.1f%%' % accuracy)
  print('loss: %.4f ' %loss)

print_results()
get_accuracy()
# Out:
# day 0 to 1 | predicted trend: 1 | target trend: 1 | predicted price: $38.31 | actual price: $38.31
# difference from predicted price to actual price: $0.00
# day 1 to 2 | predicted trend: 0 | target trend: 0 | predicted price: $38.43 | actual price: $38.99
# difference from predicted price to actual price: $-0.56
# day 2 to 3 | predicted trend: 0 | target trend: 1 | predicted price: $38.38 | actual price: $38.55
# difference from predicted price to actual price: $-0.16
# day 3 to 4 | predicted trend: 0 | target trend: 0 | predicted price: $38.31 | actual price: $38.90
# difference from predicted price to actual price: $-0.59
# day 4 to 5 | predicted trend: 0 | target trend: 0 | predicted price: $38.11 | actual price: $38.70
# difference from predicted price to actual price: $-0.59
# day 5 to 6 | predicted trend: 1 | target trend: 1 | predicted price: $38.05 | actual price: $38.51
# difference from predicted price to actual price: $-0.46
# day 6 to 7 | predicted trend: 0 | target trend: 1 | predicted price: $38.32 | actual price: $38.58
# difference from predicted price to actual price: $-0.26
# day 7 to 8 | predicted trend: 0 | target trend: 0 | predicted price: $38.20 | actual price: $39.04
# difference from predicted price to actual price: $-0.84
# day 8 to 9 | predicted trend: 0 | target trend: 1 | predicted price: $37.95 | actual price: $38.82
# difference from predicted price to actual price: $-0.87
# day 9 to 10 | predicted trend: 0 | target trend: 0 | predicted price: $37.87 | actual price: $38.54
# difference from predicted price to actual price: $-0.67
# day 10 to 11 | predicted trend: 0 | target trend: 0 | predicted price: $37.67 | actual price: $38.66
# difference from predicted price to actual price: $-0.99
# day 11 to 12 | predicted trend: 1 | target trend: 1 | predicted price: $37.50 | actual price: $38.14
# difference from predicted price to actual price: $-0.64
# day 12 to 13 | predicted trend: 1 | target trend: 1 | predicted price: $38.20 | actual price: $38.32
# difference from predicted price to actual price: $-0.12
# day 13 to 14 | predicted trend: 0 | target trend: 0 | predicted price: $38.69 | actual price: $39.54
# difference from predicted price to actual price: $-0.85
# day 14 to 15 | predicted trend: 1 | target trend: 1 | predicted price: $38.59 | actual price: $39.30
# difference from predicted price to actual price: $-0.71
# day 15 to 16 | predicted trend: 1 | target trend: 1 | predicted price: $39.32 | actual price: $39.74
# difference from predicted price to actual price: $-0.42
# day 16 to 17 | predicted trend: 1 | target trend: 1 | predicted price: $40.18 | actual price: $40.76
# difference from predicted price to actual price: $-0.58
# day 17 to 18 | predicted trend: 1 | target trend: 1 | predicted price: $40.50 | actual price: $41.47
# difference from predicted price to actual price: $-0.97
# day 18 to 19 | predicted trend: 0 | target trend: 1 | predicted price: $40.64 | actual price: $41.40
# difference from predicted price to actual price: $-0.76
# day 19 to 20 | predicted trend: 0 | target trend: 0 | predicted price: $40.50 | actual price: $41.75
# difference from predicted price to actual price: $-1.25
# day 20 to 21 | predicted trend: 1 | target trend: 1 | predicted price: $40.39 | actual price: $41.12
# difference from predicted price to actual price: $-0.73
# day 21 to 22 | predicted trend: 1 | target trend: 1 | predicted price: $40.58 | actual price: $41.53
# difference from predicted price to actual price: $-0.95
# day 22 to 23 | predicted trend: 0 | target trend: 1 | predicted price: $40.73 | actual price: $41.50
# difference from predicted price to actual price: $-0.77
# day 23 to 24 | predicted trend: 0 | target trend: 0 | predicted price: $40.70 | actual price: $41.82
# difference from predicted price to actual price: $-1.12
# day 24 to 25 | predicted trend: 0 | target trend: 0 | predicted price: $40.33 | actual price: $41.45
# difference from predicted price to actual price: $-1.12
# day 25 to 26 | predicted trend: 0 | target trend: 0 | predicted price: $40.16 | actual price: $41.08
# difference from predicted price to actual price: $-0.92
# day 26 to 27 | predicted trend: 0 | target trend: 1 | predicted price: $39.35 | actual price: $41.10
# difference from predicted price to actual price: $-1.75
# day 27 to 28 | predicted trend: 0 | target trend: 0 | predicted price: $38.90 | actual price: $42.70
# difference from predicted price to actual price: $-3.80
# day 28 to 29 | predicted trend: 1 | target trend: 1 | predicted price: $38.64 | actual price: $41.99
# difference from predicted price to actual price: $-3.35
# day 29 to 30 | predicted trend: 1 | target trend: 1 | predicted price: $39.09 | actual price: $42.17
# difference from predicted price to actual price: $-3.08
# day 30 to 31 | predicted trend: 0 | target trend: 0 | predicted price: $39.34 | actual price: $42.90
# difference from predicted price to actual price: $-3.56
# day 31 to 32 | predicted trend: 0 | target trend: 0 | predicted price: $39.19 | actual price: $42.66
# difference from predicted price to actual price: $-3.47
# day 32 to 33 | predicted trend: 1 | target trend: 1 | predicted price: $39.13 | actual price: $42.60
# difference from predicted price to actual price: $-3.47
# day 33 to 34 | predicted trend: 1 | target trend: 1 | predicted price: $39.51 | actual price: $42.54
# difference from predicted price to actual price: $-3.03
# day 34 to 35 | predicted trend: 1 | target trend: 1 | predicted price: $39.99 | actual price: $43.36
# difference from predicted price to actual price: $-3.37
# day 35 to 36 | predicted trend: 1 | target trend: 1 | predicted price: $40.20 | actual price: $43.50
# difference from predicted price to actual price: $-3.30
# day 36 to 37 | predicted trend: 0 | target trend: 1 | predicted price: $40.32 | actual price: $43.78
# difference from predicted price to actual price: $-3.46
# day 37 to 38 | predicted trend: 0 | target trend: 0 | predicted price: $40.14 | actual price: $43.74
# difference from predicted price to actual price: $-3.60
# day 38 to 39 | predicted trend: 1 | target trend: 1 | predicted price: $39.90 | actual price: $43.42
# difference from predicted price to actual price: $-3.52
# day 39 to 40 | predicted trend: 1 | target trend: 1 | predicted price: $40.05 | actual price: $43.27
# difference from predicted price to actual price: $-3.22
# day 40 to 41 | predicted trend: 1 | target trend: 1 | predicted price: $40.62 | actual price: $43.71
# difference from predicted price to actual price: $-3.09
# day 41 to 42 | predicted trend: 0 | target trend: 1 | predicted price: $41.29 | actual price: $44.42
# difference from predicted price to actual price: $-3.13
# day 42 to 43 | predicted trend: 0 | target trend: 0 | predicted price: $40.92 | actual price: $45.04
# difference from predicted price to actual price: $-4.12
# day 43 to 44 | predicted trend: 0 | target trend: 0 | predicted price: $40.81 | actual price: $45.15
# difference from predicted price to actual price: $-4.34
# day 44 to 45 | predicted trend: 0 | target trend: 1 | predicted price: $40.62 | actual price: $44.81
# difference from predicted price to actual price: $-4.19
# day 45 to 46 | predicted trend: 0 | target trend: 0 | predicted price: $40.59 | actual price: $44.77
# difference from predicted price to actual price: $-4.18
# day 46 to 47 | predicted trend: 0 | target trend: 0 | predicted price: $40.39 | actual price: $44.86
# difference from predicted price to actual price: $-4.47
# day 47 to 48 | predicted trend: 0 | target trend: 0 | predicted price: $40.26 | actual price: $45.18
# difference from predicted price to actual price: $-4.92
# day 48 to 49 | predicted trend: 1 | target trend: 1 | predicted price: $40.17 | actual price: $44.60
# difference from predicted price to actual price: $-4.43
# day 49 to 50 | predicted trend: 1 | target trend: 1 | predicted price: $40.29 | actual price: $45.00
# difference from predicted price to actual price: $-4.71
# day 50 to 51 | predicted trend: 0 | target trend: 0 | predicted price: $40.33 | actual price: $44.84
# difference from predicted price to actual price: $-4.51
# day 51 to 52 | predicted trend: 1 | target trend: 1 | predicted price: $40.29 | actual price: $44.91
# difference from predicted price to actual price: $-4.62
# day 52 to 53 | predicted trend: 1 | target trend: 1 | predicted price: $40.32 | actual price: $44.75
# difference from predicted price to actual price: $-4.43
# day 53 to 54 | predicted trend: 0 | target trend: 1 | predicted price: $40.39 | actual price: $44.84
# difference from predicted price to actual price: $-4.45
# day 54 to 55 | predicted trend: 0 | target trend: 0 | predicted price: $40.35 | actual price: $44.89
# difference from predicted price to actual price: $-4.54
# day 55 to 56 | predicted trend: 1 | target trend: 1 | predicted price: $40.23 | actual price: $44.76
# difference from predicted price to actual price: $-4.53
# day 56 to 57 | predicted trend: 1 | target trend: 1 | predicted price: $40.28 | actual price: $45.14
# difference from predicted price to actual price: $-4.86
# day 57 to 58 | predicted trend: 1 | target trend: 1 | predicted price: $40.71 | actual price: $44.65
# difference from predicted price to actual price: $-3.94
# day 58 to 59 | predicted trend: 0 | target trend: 1 | predicted price: $41.89 | actual price: $46.00
# difference from predicted price to actual price: $-4.11
# day 59 to 60 | predicted trend: 0 | target trend: 0 | predicted price: $41.66 | actual price: $47.00
# difference from predicted price to actual price: $-5.34
# day 60 to 61 | predicted trend: 0 | target trend: 0 | predicted price: $40.91 | actual price: $46.46
# difference from predicted price to actual price: $-5.55
# day 61 to 62 | predicted trend: 0 | target trend: 0 | predicted price: $40.29 | actual price: $45.51
# difference from predicted price to actual price: $-5.22
# day 62 to 63 | predicted trend: 0 | target trend: 0 | predicted price: $39.60 | actual price: $45.22
# difference from predicted price to actual price: $-5.62
# day 63 to 64 | predicted trend: 0 | target trend: 0 | predicted price: $38.98 | actual price: $44.12
# difference from predicted price to actual price: $-5.14
# day 64 to 65 | predicted trend: 1 | target trend: 1 | predicted price: $38.77 | actual price: $43.98
# difference from predicted price to actual price: $-5.21
# day 65 to 66 | predicted trend: 1 | target trend: 1 | predicted price: $38.81 | actual price: $43.70
# difference from predicted price to actual price: $-4.89
# day 66 to 67 | predicted trend: 1 | target trend: 1 | predicted price: $39.44 | actual price: $44.06
# difference from predicted price to actual price: $-4.62
# day 67 to 68 | predicted trend: 0 | target trend: 0 | predicted price: $39.71 | actual price: $44.96
# difference from predicted price to actual price: $-5.25
# day 68 to 69 | predicted trend: 0 | target trend: 0 | predicted price: $39.50 | actual price: $44.60
# difference from predicted price to actual price: $-5.10
# day 69 to 70 | predicted trend: 0 | target trend: 0 | predicted price: $39.31 | actual price: $44.55
# difference from predicted price to actual price: $-5.24
# day 70 to 71 | predicted trend: 0 | target trend: 0 | predicted price: $39.09 | actual price: $44.21
# difference from predicted price to actual price: $-5.12
# day 71 to 72 | predicted trend: 0 | target trend: 0 | predicted price: $38.32 | actual price: $44.12
# difference from predicted price to actual price: $-5.80
# day 72 to 73 | predicted trend: 1 | target trend: 0 | predicted price: $37.42 | actual price: $42.66
# difference from predicted price to actual price: $-5.24
# day 73 to 74 | predicted trend: 1 | target trend: 1 | predicted price: $37.48 | actual price: $42.32
# difference from predicted price to actual price: $-4.84
# day 74 to 75 | predicted trend: 1 | target trend: 0 | predicted price: $37.69 | actual price: $42.78
# difference from predicted price to actual price: $-5.09
# day 75 to 76 | predicted trend: 1 | target trend: 1 | predicted price: $37.76 | actual price: $42.75
# difference from predicted price to actual price: $-4.99
# day 76 to 77 | predicted trend: 1 | target trend: 1 | predicted price: $37.84 | actual price: $42.65
# difference from predicted price to actual price: $-4.81
# day 77 to 78 | predicted trend: 1 | target trend: 1 | predicted price: $38.01 | actual price: $42.92
# difference from predicted price to actual price: $-4.91
# day 78 to 79 | predicted trend: 1 | target trend: 1 | predicted price: $38.38 | actual price: $42.98
# difference from predicted price to actual price: $-4.60
# day 79 to 80 | predicted trend: 0 | target trend: 1 | predicted price: $39.09 | actual price: $43.67
# difference from predicted price to actual price: $-4.58
# day 80 to 81 | predicted trend: 0 | target trend: 0 | predicted price: $39.00 | actual price: $44.39
# difference from predicted price to actual price: $-5.39
# day 81 to 82 | predicted trend: 1 | target trend: 1 | predicted price: $38.74 | actual price: $43.84
# difference from predicted price to actual price: $-5.10
# day 82 to 83 | predicted trend: 0 | target trend: 1 | predicted price: $38.97 | actual price: $43.86
# difference from predicted price to actual price: $-4.89
# day 83 to 84 | predicted trend: 0 | target trend: 0 | predicted price: $38.84 | actual price: $44.30
# difference from predicted price to actual price: $-5.46
# day 84 to 85 | predicted trend: 0 | target trend: 0 | predicted price: $38.34 | actual price: $43.60
# difference from predicted price to actual price: $-5.26
# day 85 to 86 | predicted trend: 0 | target trend: 0 | predicted price: $37.91 | actual price: $43.31
# difference from predicted price to actual price: $-5.40
# day 86 to 87 | predicted trend: 1 | target trend: 1 | predicted price: $37.90 | actual price: $42.74
# difference from predicted price to actual price: $-4.84
# day 87 to 88 | predicted trend: 1 | target trend: 1 | predicted price: $38.14 | actual price: $43.33
# difference from predicted price to actual price: $-5.19
# day 88 to 89 | predicted trend: 1 | target trend: 1 | predicted price: $38.25 | actual price: $43.22
# difference from predicted price to actual price: $-4.97
# day 89 to 90 | predicted trend: 0 | target trend: 1 | predicted price: $39.86 | actual price: $43.55
# difference from predicted price to actual price: $-3.69
# day 90 to 91 | predicted trend: 0 | target trend: 0 | predicted price: $38.99 | actual price: $46.43
# difference from predicted price to actual price: $-7.44
# day 91 to 92 | predicted trend: 0 | target trend: 0 | predicted price: $38.24 | actual price: $45.28
# difference from predicted price to actual price: $-7.04
# day 92 to 93 | predicted trend: 0 | target trend: 0 | predicted price: $37.77 | actual price: $44.92
# difference from predicted price to actual price: $-7.15
# day 93 to 94 | predicted trend: 1 | target trend: 1 | predicted price: $37.33 | actual price: $44.34
# difference from predicted price to actual price: $-7.01
# day 94 to 95 | predicted trend: 1 | target trend: 1 | predicted price: $37.63 | actual price: $44.04
# difference from predicted price to actual price: $-6.41
# day 95 to 96 | predicted trend: 1 | target trend: 1 | predicted price: $38.56 | actual price: $44.95
# difference from predicted price to actual price: $-6.39
# day 96 to 97 | predicted trend: 0 | target trend: 0 | predicted price: $39.08 | actual price: $45.90
# difference from predicted price to actual price: $-6.82
# day 97 to 98 | predicted trend: 1 | target trend: 1 | predicted price: $38.75 | actual price: $45.99
# difference from predicted price to actual price: $-7.24
# day 98 to 99 | predicted trend: 1 | target trend: 1 | predicted price: $38.75 | actual price: $45.23
# difference from predicted price to actual price: $-6.48
# day 99 to 100 | predicted trend: 1 | target trend: 1 | predicted price: $38.99 | actual price: $46.00
# difference from predicted price to actual price: $-7.01
# day 100 to 101 | predicted trend: 1 | target trend: 1 | predicted price: $39.34 | actual price: $45.71
# difference from predicted price to actual price: $-6.37
# day 101 to 102 | predicted trend: 1 | target trend: 1 | predicted price: $40.00 | actual price: $46.69
# difference from predicted price to actual price: $-6.69
# day 102 to 103 | predicted trend: 1 | target trend: 1 | predicted price: $40.03 | actual price: $47.03
# difference from predicted price to actual price: $-7.00
# day 103 to 104 | predicted trend: 1 | target trend: 1 | predicted price: $40.06 | actual price: $46.76
# difference from predicted price to actual price: $-6.70
# day 104 to 105 | predicted trend: 1 | target trend: 1 | predicted price: $40.49 | actual price: $47.09
# difference from predicted price to actual price: $-6.60
# day 105 to 106 | predicted trend: 0 | target trend: 1 | predicted price: $41.12 | actual price: $47.62
# difference from predicted price to actual price: $-6.50
# day 106 to 107 | predicted trend: 0 | target trend: 0 | predicted price: $40.81 | actual price: $48.35
# difference from predicted price to actual price: $-7.54
# day 107 to 108 | predicted trend: 0 | target trend: 0 | predicted price: $40.66 | actual price: $48.25
# difference from predicted price to actual price: $-7.59
# day 108 to 109 | predicted trend: 1 | target trend: 1 | predicted price: $40.62 | actual price: $48.05
# difference from predicted price to actual price: $-7.43
# day 109 to 110 | predicted trend: 0 | target trend: 1 | predicted price: $40.62 | actual price: $48.17
# difference from predicted price to actual price: $-7.55
# day 110 to 111 | predicted trend: 0 | target trend: 0 | predicted price: $40.58 | actual price: $48.04
# difference from predicted price to actual price: $-7.46
# day 111 to 112 | predicted trend: 0 | target trend: 1 | predicted price: $40.34 | actual price: $48.26
# difference from predicted price to actual price: $-7.92
# day 112 to 113 | predicted trend: 0 | target trend: 0 | predicted price: $40.29 | actual price: $48.52
# difference from predicted price to actual price: $-8.23
# day 113 to 114 | predicted trend: 0 | target trend: 0 | predicted price: $40.22 | actual price: $48.35
# difference from predicted price to actual price: $-8.13
# day 114 to 115 | predicted trend: 0 | target trend: 0 | predicted price: $39.95 | actual price: $48.38
# difference from predicted price to actual price: $-8.43
# day 115 to 116 | predicted trend: 0 | target trend: 0 | predicted price: $39.64 | actual price: $47.80
# difference from predicted price to actual price: $-8.16
# day 116 to 117 | predicted trend: 0 | target trend: 0 | predicted price: $39.50 | actual price: $47.77
# difference from predicted price to actual price: $-8.27
# day 117 to 118 | predicted trend: 1 | target trend: 0 | predicted price: $39.21 | actual price: $47.51
# difference from predicted price to actual price: $-8.30
# day 118 to 119 | predicted trend: 1 | target trend: 1 | predicted price: $39.21 | actual price: $47.19
# difference from predicted price to actual price: $-7.98
# day 119 to 120 | predicted trend: 1 | target trend: 1 | predicted price: $39.43 | actual price: $47.50
# difference from predicted price to actual price: $-8.07
# day 120 to 121 | predicted trend: 1 | target trend: 0 | predicted price: $39.49 | actual price: $47.62
# difference from predicted price to actual price: $-8.13
# day 121 to 122 | predicted trend: 1 | target trend: 1 | predicted price: $39.57 | actual price: $47.38
# difference from predicted price to actual price: $-7.81
# day 122 to 123 | predicted trend: 0 | target trend: 0 | predicted price: $39.66 | actual price: $47.45
# difference from predicted price to actual price: $-7.79
# day 123 to 124 | predicted trend: 1 | target trend: 0 | predicted price: $39.52 | actual price: $47.55
# difference from predicted price to actual price: $-8.03
# day 124 to 125 | predicted trend: 1 | target trend: 1 | predicted price: $39.63 | actual price: $47.17
# difference from predicted price to actual price: $-7.54
# day 125 to 126 | predicted trend: 0 | target trend: 0 | predicted price: $39.74 | actual price: $47.32
# difference from predicted price to actual price: $-7.58
# day 126 to 127 | predicted trend: 1 | target trend: 0 | predicted price: $39.51 | actual price: $47.38
# difference from predicted price to actual price: $-7.87
# day 127 to 128 | predicted trend: 1 | target trend: 1 | predicted price: $39.52 | actual price: $46.87
# difference from predicted price to actual price: $-7.35
# day 128 to 129 | predicted trend: 0 | target trend: 0 | predicted price: $39.65 | actual price: $47.37
# difference from predicted price to actual price: $-7.72
# day 129 to 130 | predicted trend: 0 | target trend: 0 | predicted price: $39.15 | actual price: $47.14
# difference from predicted price to actual price: $-7.99
# day 130 to 131 | predicted trend: 0 | target trend: 0 | predicted price: $38.55 | actual price: $46.37
# difference from predicted price to actual price: $-7.82
# day 131 to 132 | predicted trend: 0 | target trend: 0 | predicted price: $38.09 | actual price: $45.94
# difference from predicted price to actual price: $-7.85
# day 132 to 133 | predicted trend: 1 | target trend: 0 | predicted price: $37.50 | actual price: $45.44
# difference from predicted price to actual price: $-7.94
# day 133 to 134 | predicted trend: 1 | target trend: 1 | predicted price: $37.72 | actual price: $44.77
# difference from predicted price to actual price: $-7.05
# day 134 to 135 | predicted trend: 1 | target trend: 1 | predicted price: $37.88 | actual price: $45.01
# difference from predicted price to actual price: $-7.13
# day 135 to 136 | predicted trend: 1 | target trend: 1 | predicted price: $38.30 | actual price: $45.10
# difference from predicted price to actual price: $-6.80
# day 136 to 137 | predicted trend: 1 | target trend: 1 | predicted price: $38.88 | actual price: $45.85
# difference from predicted price to actual price: $-6.97
# day 137 to 138 | predicted trend: 0 | target trend: 0 | predicted price: $39.03 | actual price: $46.25
# difference from predicted price to actual price: $-7.22
# day 138 to 139 | predicted trend: 1 | target trend: 1 | predicted price: $38.69 | actual price: $45.55
# difference from predicted price to actual price: $-6.86
# day 139 to 140 | predicted trend: 1 | target trend: 1 | predicted price: $38.72 | actual price: $45.58
# difference from predicted price to actual price: $-6.86
# day 140 to 141 | predicted trend: 1 | target trend: 1 | predicted price: $38.87 | actual price: $45.50
# difference from predicted price to actual price: $-6.63
# day 141 to 142 | predicted trend: 1 | target trend: 1 | predicted price: $39.22 | actual price: $45.88
# difference from predicted price to actual price: $-6.66
# day 142 to 143 | predicted trend: 1 | target trend: 1 | predicted price: $39.28 | actual price: $46.21
# difference from predicted price to actual price: $-6.93
# day 143 to 144 | predicted trend: 0 | target trend: 1 | predicted price: $39.62 | actual price: $45.76
# difference from predicted price to actual price: $-6.14
# day 144 to 145 | predicted trend: 0 | target trend: 0 | predicted price: $39.05 | actual price: $46.88
# difference from predicted price to actual price: $-7.83
# day 145 to 146 | predicted trend: 1 | target trend: 1 | predicted price: $38.94 | actual price: $46.89
# difference from predicted price to actual price: $-7.95
# day 146 to 147 | predicted trend: 1 | target trend: 1 | predicted price: $39.30 | actual price: $47.11
# difference from predicted price to actual price: $-7.81
# day 147 to 148 | predicted trend: 0 | target trend: 1 | predicted price: $39.75 | actual price: $47.62
# difference from predicted price to actual price: $-7.87
# day 148 to 149 | predicted trend: 0 | target trend: 0 | predicted price: $39.52 | actual price: $48.00
# difference from predicted price to actual price: $-8.48
# day 149 to 150 | predicted trend: 0 | target trend: 0 | predicted price: $39.35 | actual price: $48.07
# difference from predicted price to actual price: $-8.72
# day 150 to 151 | predicted trend: 0 | target trend: 1 | predicted price: $39.30 | actual price: $47.66
# difference from predicted price to actual price: $-8.36
# day 151 to 152 | predicted trend: 0 | target trend: 0 | predicted price: $39.04 | actual price: $48.17
# difference from predicted price to actual price: $-9.13
# day 152 to 153 | predicted trend: 0 | target trend: 1 | predicted price: $37.28 | actual price: $48.19
# difference from predicted price to actual price: $-10.91
# day 153 to 154 | predicted trend: 0 | target trend: 0 | predicted price: $35.35 | actual price: $51.68
# difference from predicted price to actual price: $-16.33
# day 154 to 155 | predicted trend: 0 | target trend: 1 | predicted price: $35.26 | actual price: $52.05
# difference from predicted price to actual price: $-16.79
# day 155 to 156 | predicted trend: 0 | target trend: 0 | predicted price: $35.25 | actual price: $51.87
# difference from predicted price to actual price: $-16.62
# day 156 to 157 | predicted trend: 0 | target trend: 0 | predicted price: $35.21 | actual price: $52.07
# difference from predicted price to actual price: $-16.86
# day 157 to 158 | predicted trend: 1 | target trend: 1 | predicted price: $34.91 | actual price: $51.79
# difference from predicted price to actual price: $-16.88
# day 158 to 159 | predicted trend: 1 | target trend: 1 | predicted price: $35.02 | actual price: $51.48
# difference from predicted price to actual price: $-16.46
# day 159 to 160 | predicted trend: 0 | target trend: 0 | predicted price: $35.13 | actual price: $52.00
# difference from predicted price to actual price: $-16.87
# day 160 to 161 | predicted trend: 0 | target trend: 0 | predicted price: $34.88 | actual price: $51.71
# difference from predicted price to actual price: $-16.83
# day 161 to 162 | predicted trend: 1 | target trend: 1 | predicted price: $34.69 | actual price: $51.50
# difference from predicted price to actual price: $-16.81
# day 162 to 163 | predicted trend: 0 | target trend: 0 | predicted price: $34.83 | actual price: $52.10
# difference from predicted price to actual price: $-17.27
# day 163 to 164 | predicted trend: 0 | target trend: 0 | predicted price: $34.59 | actual price: $51.79
# difference from predicted price to actual price: $-17.20
# day 164 to 165 | predicted trend: 1 | target trend: 0 | predicted price: $33.74 | actual price: $51.61
# difference from predicted price to actual price: $-17.87
# day 165 to 166 | predicted trend: 1 | target trend: 1 | predicted price: $34.02 | actual price: $50.09
# difference from predicted price to actual price: $-16.07
# day 166 to 167 | predicted trend: 0 | target trend: 0 | predicted price: $34.44 | actual price: $51.05
# difference from predicted price to actual price: $-16.61
# day 167 to 168 | predicted trend: 1 | target trend: 0 | predicted price: $33.72 | actual price: $50.93
# difference from predicted price to actual price: $-17.21
# day 168 to 169 | predicted trend: 1 | target trend: 1 | predicted price: $34.16 | actual price: $49.62
# difference from predicted price to actual price: $-15.46
# day 169 to 170 | predicted trend: 1 | target trend: 1 | predicted price: $34.76 | actual price: $50.06
# difference from predicted price to actual price: $-15.30
# day 170 to 171 | predicted trend: 1 | target trend: 1 | predicted price: $35.68 | actual price: $50.82
# difference from predicted price to actual price: $-15.14
# day 171 to 172 | predicted trend: 0 | target trend: 0 | predicted price: $36.42 | actual price: $51.90
# difference from predicted price to actual price: $-15.48
# day 172 to 173 | predicted trend: 0 | target trend: 0 | predicted price: $36.24 | actual price: $52.31
# difference from predicted price to actual price: $-16.07
# day 173 to 174 | predicted trend: 1 | target trend: 1 | predicted price: $36.02 | actual price: $51.54
# difference from predicted price to actual price: $-15.52
# day 174 to 175 | predicted trend: 1 | target trend: 1 | predicted price: $36.33 | actual price: $51.87
# difference from predicted price to actual price: $-15.54
# day 175 to 176 | predicted trend: 1 | target trend: 1 | predicted price: $36.76 | actual price: $52.15
# difference from predicted price to actual price: $-15.39
# day 176 to 177 | predicted trend: 0 | target trend: 1 | predicted price: $37.42 | actual price: $52.73
# difference from predicted price to actual price: $-15.31
# day 177 to 178 | predicted trend: 0 | target trend: 0 | predicted price: $37.41 | actual price: $53.47
# difference from predicted price to actual price: $-16.06
# day 178 to 179 | predicted trend: 1 | target trend: 1 | predicted price: $37.20 | actual price: $52.75
# difference from predicted price to actual price: $-15.55
# day 179 to 180 | predicted trend: 1 | target trend: 1 | predicted price: $37.86 | actual price: $53.06
# difference from predicted price to actual price: $-15.20
# day 180 to 181 | predicted trend: 1 | target trend: 1 | predicted price: $38.29 | actual price: $54.07
# difference from predicted price to actual price: $-15.78
# day 181 to 182 | predicted trend: 0 | target trend: 1 | predicted price: $38.32 | actual price: $53.91
# difference from predicted price to actual price: $-15.59
# day 182 to 183 | predicted trend: 0 | target trend: 0 | predicted price: $37.84 | actual price: $54.00
# difference from predicted price to actual price: $-16.16
# day 183 to 184 | predicted trend: 0 | target trend: 0 | predicted price: $37.84 | actual price: $54.87
# difference from predicted price to actual price: $-17.03
# day 184 to 185 | predicted trend: 1 | target trend: 1 | predicted price: $37.71 | actual price: $54.01
# difference from predicted price to actual price: $-16.30
# day 185 to 186 | predicted trend: 0 | target trend: 1 | predicted price: $38.21 | actual price: $54.61
# difference from predicted price to actual price: $-16.40
# day 186 to 187 | predicted trend: 0 | target trend: 0 | predicted price: $37.89 | actual price: $55.01
# difference from predicted price to actual price: $-17.12
# day 187 to 188 | predicted trend: 0 | target trend: 0 | predicted price: $37.84 | actual price: $55.24
# difference from predicted price to actual price: $-17.40
# day 188 to 189 | predicted trend: 0 | target trend: 0 | predicted price: $37.74 | actual price: $54.90
# difference from predicted price to actual price: $-17.16
# day 189 to 190 | predicted trend: 1 | target trend: 1 | predicted price: $37.00 | actual price: $55.05
# difference from predicted price to actual price: $-18.05
# day 190 to 191 | predicted trend: 1 | target trend: 1 | predicted price: $37.10 | actual price: $53.42
# difference from predicted price to actual price: $-16.32
# day 191 to 192 | predicted trend: 1 | target trend: 1 | predicted price: $38.31 | actual price: $54.85
# difference from predicted price to actual price: $-16.54
# day 192 to 193 | predicted trend: 1 | target trend: 1 | predicted price: $38.68 | actual price: $55.84
# difference from predicted price to actual price: $-17.16
# day 193 to 194 | predicted trend: 0 | target trend: 1 | predicted price: $39.54 | actual price: $55.59
# difference from predicted price to actual price: $-16.05
# day 194 to 195 | predicted trend: 0 | target trend: 0 | predicted price: $38.57 | actual price: $57.56
# difference from predicted price to actual price: $-18.99
# day 195 to 196 | predicted trend: 0 | target trend: 0 | predicted price: $38.51 | actual price: $57.54
# difference from predicted price to actual price: $-19.03
# day 196 to 197 | predicted trend: 0 | target trend: 0 | predicted price: $38.11 | actual price: $57.45
# difference from predicted price to actual price: $-19.34
# day 197 to 198 | predicted trend: 0 | target trend: 0 | predicted price: $37.37 | actual price: $56.73
# difference from predicted price to actual price: $-19.36
# day 198 to 199 | predicted trend: 1 | target trend: 1 | predicted price: $37.15 | actual price: $55.98
# difference from predicted price to actual price: $-18.83
# day 199 to 200 | predicted trend: 1 | target trend: 1 | predicted price: $37.29 | actual price: $56.28
# difference from predicted price to actual price: $-18.99
# day 200 to 201 | predicted trend: 1 | target trend: 1 | predicted price: $37.46 | actual price: $56.26
# difference from predicted price to actual price: $-18.80
# day 201 to 202 | predicted trend: 0 | target trend: 0 | predicted price: $37.76 | actual price: $56.62
# difference from predicted price to actual price: $-18.86
# day 202 to 203 | predicted trend: 1 | target trend: 1 | predicted price: $37.65 | actual price: $56.87
# difference from predicted price to actual price: $-19.22
# day 203 to 204 | predicted trend: 0 | target trend: 1 | predicted price: $37.77 | actual price: $56.85
# difference from predicted price to actual price: $-19.08
# day 204 to 205 | predicted trend: 0 | target trend: 0 | predicted price: $37.72 | actual price: $57.12
# difference from predicted price to actual price: $-19.40
# day 205 to 206 | predicted trend: 0 | target trend: 0 | predicted price: $37.47 | actual price: $56.74
# difference from predicted price to actual price: $-19.27
# day 206 to 207 | predicted trend: 0 | target trend: 0 | predicted price: $37.20 | actual price: $56.63
# difference from predicted price to actual price: $-19.43
# day 207 to 208 | predicted trend: 0 | target trend: 0 | predicted price: $36.70 | actual price: $56.19
# difference from predicted price to actual price: $-19.49
# day 208 to 209 | predicted trend: 1 | target trend: 1 | predicted price: $36.60 | actual price: $55.63
# difference from predicted price to actual price: $-19.03
# day 209 to 210 | predicted trend: 0 | target trend: 0 | predicted price: $36.75 | actual price: $55.99
# difference from predicted price to actual price: $-19.24
# day 210 to 211 | predicted trend: 0 | target trend: 0 | predicted price: $36.45 | actual price: $55.94
# difference from predicted price to actual price: $-19.49
# day 211 to 212 | predicted trend: 0 | target trend: 0 | predicted price: $36.10 | actual price: $55.38
# difference from predicted price to actual price: $-19.28
# day 212 to 213 | predicted trend: 1 | target trend: 0 | predicted price: $35.63 | actual price: $55.25
# difference from predicted price to actual price: $-19.62
# day 213 to 214 | predicted trend: 1 | target trend: 1 | predicted price: $37.04 | actual price: $54.44
# difference from predicted price to actual price: $-17.40
# day 214 to 215 | predicted trend: 1 | target trend: 1 | predicted price: $40.13 | actual price: $58.06
# difference from predicted price to actual price: $-17.93
# day 215 to 216 | predicted trend: 1 | target trend: 0 | predicted price: $40.35 | actual price: $60.63
# difference from predicted price to actual price: $-20.28
# day 216 to 217 | predicted trend: 1 | target trend: 1 | predicted price: $41.88 | actual price: $58.50
# difference from predicted price to actual price: $-16.62
# day 217 to 218 | predicted trend: 1 | target trend: 1 | predicted price: $41.99 | actual price: $57.58
# difference from predicted price to actual price: $-15.59
# day 218 to 219 | predicted trend: 1 | target trend: 1 | predicted price: $42.41 | actual price: $58.73
# difference from predicted price to actual price: $-16.32
# day 219 to 220 | predicted trend: 0 | target trend: 1 | predicted price: $42.92 | actual price: $58.42
# difference from predicted price to actual price: $-15.50
# day 220 to 221 | predicted trend: 0 | target trend: 0 | predicted price: $42.34 | actual price: $59.74
# difference from predicted price to actual price: $-17.40
# day 221 to 222 | predicted trend: 0 | target trend: 1 | predicted price: $42.23 | actual price: $59.58
# difference from predicted price to actual price: $-17.35
# day 222 to 223 | predicted trend: 0 | target trend: 0 | predicted price: $42.16 | actual price: $59.53
# difference from predicted price to actual price: $-17.37
# day 223 to 224 | predicted trend: 0 | target trend: 0 | predicted price: $42.09 | actual price: $59.73
# difference from predicted price to actual price: $-17.64
# day 224 to 225 | predicted trend: 0 | target trend: 1 | predicted price: $42.02 | actual price: $59.67
# difference from predicted price to actual price: $-17.65
# day 225 to 226 | predicted trend: 0 | target trend: 0 | predicted price: $41.72 | actual price: $59.60
# difference from predicted price to actual price: $-17.88
# day 226 to 227 | predicted trend: 0 | target trend: 1 | predicted price: $41.51 | actual price: $59.06
# difference from predicted price to actual price: $-17.55
# day 227 to 228 | predicted trend: 0 | target trend: 0 | predicted price: $41.01 | actual price: $59.19
# difference from predicted price to actual price: $-18.18
# day 228 to 229 | predicted trend: 1 | target trend: 1 | predicted price: $40.55 | actual price: $58.06
# difference from predicted price to actual price: $-17.51
# day 229 to 230 | predicted trend: 1 | target trend: 1 | predicted price: $41.08 | actual price: $58.26
# difference from predicted price to actual price: $-17.18
# day 230 to 231 | predicted trend: 1 | target trend: 1 | predicted price: $41.44 | actual price: $59.12
# difference from predicted price to actual price: $-17.68
# day 231 to 232 | predicted trend: 0 | target trend: 1 | predicted price: $41.56 | actual price: $58.99
# difference from predicted price to actual price: $-17.43
# day 232 to 233 | predicted trend: 0 | target trend: 0 | predicted price: $41.41 | actual price: $59.35
# difference from predicted price to actual price: $-17.94
# day 233 to 234 | predicted trend: 1 | target trend: 1 | predicted price: $41.08 | actual price: $59.28
# difference from predicted price to actual price: $-18.20
# day 234 to 235 | predicted trend: 1 | target trend: 1 | predicted price: $41.66 | actual price: $58.68
# difference from predicted price to actual price: $-17.02
# day 235 to 236 | predicted trend: 0 | target trend: 1 | predicted price: $43.11 | actual price: $60.44
# difference from predicted price to actual price: $-17.33
# day 236 to 237 | predicted trend: 0 | target trend: 0 | predicted price: $42.82 | actual price: $61.59
# difference from predicted price to actual price: $-18.77
# day 237 to 238 | predicted trend: 1 | target trend: 1 | predicted price: $42.78 | actual price: $61.02
# difference from predicted price to actual price: $-18.24
# day 238 to 239 | predicted trend: 0 | target trend: 1 | predicted price: $42.82 | actual price: $61.50
# difference from predicted price to actual price: $-18.68
# day 239 to 240 | predicted trend: 0 | target trend: 0 | predicted price: $42.66 | actual price: $60.93
# difference from predicted price to actual price: $-18.27
# day 240 to 241 | predicted trend: 0 | target trend: 0 | predicted price: $42.35 | actual price: $61.18
# difference from predicted price to actual price: $-18.83
# day 241 to 242 | predicted trend: 0 | target trend: 0 | predicted price: $40.81 | actual price: $60.30
# difference from predicted price to actual price: $-19.49
# day 242 to 243 | predicted trend: 0 | target trend: 1 | predicted price: $39.65 | actual price: $58.11
# difference from predicted price to actual price: $-18.46
# day 243 to 244 | predicted trend: 0 | target trend: 0 | predicted price: $39.40 | actual price: $57.98
# difference from predicted price to actual price: $-18.58
# day 244 to 245 | predicted trend: 0 | target trend: 1 | predicted price: $38.83 | actual price: $58.61
# difference from predicted price to actual price: $-19.78
# day 245 to 246 | predicted trend: 0 | target trend: 0 | predicted price: $38.60 | actual price: $59.12
# difference from predicted price to actual price: $-20.52
# day 246 to 247 | predicted trend: 0 | target trend: 0 | predicted price: $38.58 | actual price: $58.15
# difference from predicted price to actual price: $-19.57
# day 247 to 248 | predicted trend: 1 | target trend: 1 | predicted price: $38.42 | actual price: $59.08
# difference from predicted price to actual price: $-20.66
# day 248 to 249 | predicted trend: 1 | target trend: 1 | predicted price: $38.65 | actual price: $58.48
# difference from predicted price to actual price: $-19.83
# day 249 to 250 | predicted trend: 1 | target trend: 1 | predicted price: $39.76 | actual price: $59.54
# difference from predicted price to actual price: $-19.78
# day 250 to 251 | predicted trend: 1 | target trend: 1 | predicted price: $40.78 | actual price: $60.70
# difference from predicted price to actual price: $-19.92
# day 251 to 252 | predicted trend: 1 | target trend: 1 | predicted price: $41.79 | actual price: $61.58
# difference from predicted price to actual price: $-19.79
# day 252 to 253 | predicted trend: 1 | target trend: 1 | predicted price: $43.24 | actual price: $62.73
# difference from predicted price to actual price: $-19.49
# day 253 to 254 | predicted trend: 1 | target trend: 1 | predicted price: $43.98 | actual price: $64.48
# difference from predicted price to actual price: $-20.50
# day 254 to 255 | predicted trend: 1 | target trend: 1 | predicted price: $44.16 | actual price: $64.21
# difference from predicted price to actual price: $-20.05
# day 255 to 256 | predicted trend: 1 | target trend: 1 | predicted price: $45.80 | actual price: $64.84
# difference from predicted price to actual price: $-19.04
# day 256 to 257 | predicted trend: 0 | target trend: 1 | predicted price: $47.69 | actual price: $67.48
# difference from predicted price to actual price: $-19.79
# day 257 to 258 | predicted trend: 0 | target trend: 0 | predicted price: $47.20 | actual price: $68.62
# difference from predicted price to actual price: $-21.42
# day 258 to 259 | predicted trend: 0 | target trend: 0 | predicted price: $46.99 | actual price: $68.45
# difference from predicted price to actual price: $-21.46
# day 259 to 260 | predicted trend: 0 | target trend: 0 | predicted price: $46.67 | actual price: $68.19
# difference from predicted price to actual price: $-21.52
# day 260 to 261 | predicted trend: 0 | target trend: 1 | predicted price: $46.50 | actual price: $67.82
# difference from predicted price to actual price: $-21.32
# day 261 to 262 | predicted trend: 0 | target trend: 0 | predicted price: $46.05 | actual price: $68.54
# difference from predicted price to actual price: $-22.49
# day 262 to 263 | predicted trend: 0 | target trend: 0 | predicted price: $45.65 | actual price: $68.71
# difference from predicted price to actual price: $-23.06
# day 263 to 264 | predicted trend: 1 | target trend: 1 | predicted price: $45.24 | actual price: $67.73
# difference from predicted price to actual price: $-22.49
# day 264 to 265 | predicted trend: 1 | target trend: 1 | predicted price: $46.50 | actual price: $67.90
# difference from predicted price to actual price: $-21.40
# day 265 to 266 | predicted trend: 0 | target trend: 0 | predicted price: $46.58 | actual price: $70.25
# difference from predicted price to actual price: $-23.67
# day 266 to 267 | predicted trend: 1 | target trend: 1 | predicted price: $45.76 | actual price: $68.06
# difference from predicted price to actual price: $-22.30
# day 267 to 268 | predicted trend: 1 | target trend: 1 | predicted price: $46.12 | actual price: $68.60
# difference from predicted price to actual price: $-22.48
# day 268 to 269 | predicted trend: 0 | target trend: 1 | predicted price: $46.39 | actual price: $68.79
# difference from predicted price to actual price: $-22.40
# day 269 to 270 | predicted trend: 0 | target trend: 0 | predicted price: $46.18 | actual price: $69.14
# difference from predicted price to actual price: $-22.96
# day 270 to 271 | predicted trend: 0 | target trend: 0 | predicted price: $45.95 | actual price: $69.21
# difference from predicted price to actual price: $-23.26
# day 271 to 272 | predicted trend: 0 | target trend: 0 | predicted price: $45.44 | actual price: $68.68
# difference from predicted price to actual price: $-23.24
# day 272 to 273 | predicted trend: 0 | target trend: 0 | predicted price: $44.63 | actual price: $68.19
# difference from predicted price to actual price: $-23.56
# day 273 to 274 | predicted trend: 1 | target trend: 1 | predicted price: $44.49 | actual price: $67.06
# difference from predicted price to actual price: $-22.57
# day 274 to 275 | predicted trend: 1 | target trend: 0 | predicted price: $44.81 | actual price: $68.48
# difference from predicted price to actual price: $-23.67
# day 275 to 276 | predicted trend: 1 | target trend: 1 | predicted price: $45.10 | actual price: $67.70
# difference from predicted price to actual price: $-22.60
# day 276 to 277 | predicted trend: 1 | target trend: 1 | predicted price: $45.12 | actual price: $67.89
# difference from predicted price to actual price: $-22.77
# day 277 to 278 | predicted trend: 0 | target trend: 0 | predicted price: $45.68 | actual price: $67.66
# difference from predicted price to actual price: $-21.98
# day 278 to 279 | predicted trend: 0 | target trend: 1 | predicted price: $45.63 | actual price: $69.01
# difference from predicted price to actual price: $-23.38
# day 279 to 280 | predicted trend: 0 | target trend: 0 | predicted price: $45.60 | actual price: $67.55
# difference from predicted price to actual price: $-21.95
# day 280 to 281 | predicted trend: 0 | target trend: 0 | predicted price: $45.44 | actual price: $69.06
# difference from predicted price to actual price: $-23.62
# day 281 to 282 | predicted trend: 0 | target trend: 0 | predicted price: $43.78 | actual price: $67.22
# difference from predicted price to actual price: $-23.44
# day 282 to 283 | predicted trend: 0 | target trend: 0 | predicted price: $43.22 | actual price: $65.75
# difference from predicted price to actual price: $-22.53
# day 283 to 284 | predicted trend: 1 | target trend: 0 | predicted price: $42.15 | actual price: $66.10
# difference from predicted price to actual price: $-23.95
# day 284 to 285 | predicted trend: 1 | target trend: 1 | predicted price: $42.84 | actual price: $63.60
# difference from predicted price to actual price: $-20.76
# day 285 to 286 | predicted trend: 1 | target trend: 1 | predicted price: $43.48 | actual price: $64.71
# difference from predicted price to actual price: $-21.23
# day 286 to 287 | predicted trend: 1 | target trend: 1 | predicted price: $44.07 | actual price: $64.87
# difference from predicted price to actual price: $-20.80
# day 287 to 288 | predicted trend: 0 | target trend: 0 | predicted price: $44.67 | actual price: $65.90
# difference from predicted price to actual price: $-21.23
# day 288 to 289 | predicted trend: 0 | target trend: 0 | predicted price: $44.47 | actual price: $66.07
# difference from predicted price to actual price: $-21.60
# day 289 to 290 | predicted trend: 0 | target trend: 0 | predicted price: $42.90 | actual price: $65.50
# difference from predicted price to actual price: $-22.60
# day 290 to 291 | predicted trend: 1 | target trend: 0 | predicted price: $40.75 | actual price: $62.92
# difference from predicted price to actual price: $-22.17
# day 291 to 292 | predicted trend: 1 | target trend: 1 | predicted price: $41.94 | actual price: $61.20
# difference from predicted price to actual price: $-19.26
# day 292 to 293 | predicted trend: 1 | target trend: 1 | predicted price: $42.34 | actual price: $60.53
# difference from predicted price to actual price: $-18.19
# day 293 to 294 | predicted trend: 0 | target trend: 0 | predicted price: $43.60 | actual price: $62.00
# difference from predicted price to actual price: $-18.40
# day 294 to 295 | predicted trend: 1 | target trend: 0 | predicted price: $43.05 | actual price: $63.05
# difference from predicted price to actual price: $-20.00
# day 295 to 296 | predicted trend: 1 | target trend: 1 | predicted price: $43.98 | actual price: $60.89
# difference from predicted price to actual price: $-16.91
# day 296 to 297 | predicted trend: 1 | target trend: 1 | predicted price: $44.29 | actual price: $61.18
# difference from predicted price to actual price: $-16.89
# day 297 to 298 | predicted trend: 1 | target trend: 1 | predicted price: $44.83 | actual price: $61.50
# difference from predicted price to actual price: $-16.67
# day 298 to 299 | predicted trend: 1 | target trend: 1 | predicted price: $45.56 | actual price: $62.27
# difference from predicted price to actual price: $-16.71
# day 299 to 300 | predicted trend: 1 | target trend: 1 | predicted price: $46.43 | actual price: $62.96
# difference from predicted price to actual price: $-16.53
# ...
# difference from predicted price to actual price: $-58.31
# day 1166 to 1167 | predicted trend: 1 | target trend: 1 | predicted price: $91.12 | actual price: $145.50
# difference from predicted price to actual price: $-54.38
# day 1167 to 1168 | predicted trend: 1 | target trend: 1 | predicted price: $91.44 | actual price: $146.31
# difference from predicted price to actual price: $-54.87
# day 1168 to 1169 | predicted trend: 1 | target trend: 1 | predicted price: $91.63 | actual price: $146.14
# difference from predicted price to actual price: $-54.51
# day 1169 to 1170 | predicted trend: 1 | target trend: 1 | predicted price: $93.45 | actual price: $146.69
# difference from predicted price to actual price: $-53.24
# day 1170 to 1171 | predicted trend: 0 | target trend: 0 | predicted price: $94.35 | actual price: $149.79
# difference from predicted price to actual price: $-55.44
# day 1171 to 1172 | predicted trend: 0 | target trend: 0 | predicted price: $93.56 | actual price: $148.48
# difference from predicted price to actual price: $-54.92
# day 1172 to 1173 | predicted trend: 1 | target trend: 1 | predicted price: $93.55 | actual price: $148.21
# difference from predicted price to actual price: $-54.66
# day 1173 to 1174 | predicted trend: 1 | target trend: 1 | predicted price: $94.43 | actual price: $148.49
# difference from predicted price to actual price: $-54.06
# day 1174 to 1175 | predicted trend: 1 | target trend: 1 | predicted price: $95.56 | actual price: $149.96
# difference from predicted price to actual price: $-54.40
# day 1175 to 1176 | predicted trend: 1 | target trend: 1 | predicted price: $96.58 | actual price: $150.76
# difference from predicted price to actual price: $-54.18
# day 1176 to 1177 | predicted trend: 1 | target trend: 1 | predicted price: $97.25 | actual price: $152.00
# difference from predicted price to actual price: $-54.75
# day 1177 to 1178 | predicted trend: 0 | target trend: 1 | predicted price: $98.11 | actual price: $152.09
# difference from predicted price to actual price: $-53.98
# day 1178 to 1179 | predicted trend: 0 | target trend: 0 | predicted price: $97.17 | actual price: $153.72
# difference from predicted price to actual price: $-56.55
# day 1179 to 1180 | predicted trend: 0 | target trend: 0 | predicted price: $95.89 | actual price: $153.96
# difference from predicted price to actual price: $-58.07
# day 1180 to 1181 | predicted trend: 0 | target trend: 0 | predicted price: $94.17 | actual price: $151.15
# difference from predicted price to actual price: $-56.98
# day 1181 to 1182 | predicted trend: 1 | target trend: 1 | predicted price: $93.76 | actual price: $150.52
# difference from predicted price to actual price: $-56.76
# day 1182 to 1183 | predicted trend: 1 | target trend: 1 | predicted price: $101.25 | actual price: $150.33
# difference from predicted price to actual price: $-49.08
# day 1183 to 1184 | predicted trend: 1 | target trend: 1 | predicted price: $111.83 | actual price: $165.50
# difference from predicted price to actual price: $-53.67
# day 1184 to 1185 | predicted trend: 0 | target trend: 1 | predicted price: $116.92 | actual price: $171.50
# difference from predicted price to actual price: $-54.58
# day 1185 to 1186 | predicted trend: 0 | target trend: 0 | predicted price: $116.91 | actual price: $175.68
# difference from predicted price to actual price: $-58.77
# day 1186 to 1187 | predicted trend: 0 | target trend: 0 | predicted price: $114.25 | actual price: $171.47
# difference from predicted price to actual price: $-57.22
# day 1187 to 1188 | predicted trend: 1 | target trend: 1 | predicted price: $113.96 | actual price: $170.37
# difference from predicted price to actual price: $-56.41
# day 1188 to 1189 | predicted trend: 1 | target trend: 1 | predicted price: $115.78 | actual price: $172.06
# difference from predicted price to actual price: $-56.28
# day 1189 to 1190 | predicted trend: 0 | target trend: 1 | predicted price: $118.25 | actual price: $174.02
# difference from predicted price to actual price: $-55.77
# day 1190 to 1191 | predicted trend: 0 | target trend: 0 | predicted price: $117.18 | actual price: $177.00
# difference from predicted price to actual price: $-59.82
# day 1191 to 1192 | predicted trend: 1 | target trend: 1 | predicted price: $116.98 | actual price: $176.16
# difference from predicted price to actual price: $-59.18
# day 1192 to 1193 | predicted trend: 1 | target trend: 1 | predicted price: $117.91 | actual price: $176.59
# difference from predicted price to actual price: $-58.68
# day 1193 to 1194 | predicted trend: 0 | target trend: 1 | predicted price: $120.49 | actual price: $178.02
# difference from predicted price to actual price: $-57.53
# day 1194 to 1195 | predicted trend: 0 | target trend: 0 | predicted price: $118.50 | actual price: $181.76
# difference from predicted price to actual price: $-63.26
# day 1195 to 1196 | predicted trend: 0 | target trend: 0 | predicted price: $118.23 | actual price: $182.01
# difference from predicted price to actual price: $-63.78
# day 1196 to 1197 | predicted trend: 0 | target trend: 1 | predicted price: $117.82 | actual price: $181.23
# difference from predicted price to actual price: $-63.41
# day 1197 to 1198 | predicted trend: 0 | target trend: 0 | predicted price: $117.00 | actual price: $181.19
# difference from predicted price to actual price: $-64.19
# day 1198 to 1199 | predicted trend: 0 | target trend: 0 | predicted price: $116.90 | actual price: $182.88
# difference from predicted price to actual price: $-65.98
# day 1199 to 1200 | predicted trend: 0 | target trend: 0 | predicted price: $115.71 | actual price: $181.00
# difference from predicted price to actual price: $-65.29
# day 1200 to 1201 | predicted trend: 1 | target trend: 1 | predicted price: $115.22 | actual price: $180.50
# difference from predicted price to actual price: $-65.28
# day 1201 to 1202 | predicted trend: 1 | target trend: 0 | predicted price: $115.43 | actual price: $181.98
# difference from predicted price to actual price: $-66.55
# day 1202 to 1203 | predicted trend: 1 | target trend: 1 | predicted price: $115.83 | actual price: $180.92
# difference from predicted price to actual price: $-65.09
# day 1203 to 1204 | predicted trend: 1 | target trend: 1 | predicted price: $116.41 | actual price: $181.18
# difference from predicted price to actual price: $-64.77
# day 1204 to 1205 | predicted trend: 1 | target trend: 1 | predicted price: $117.22 | actual price: $182.08
# difference from predicted price to actual price: $-64.86
# day 1205 to 1206 | predicted trend: 0 | target trend: 1 | predicted price: $118.06 | actual price: $182.80
# difference from predicted price to actual price: $-64.74
# day 1206 to 1207 | predicted trend: 0 | target trend: 0 | predicted price: $117.30 | actual price: $183.75
# difference from predicted price to actual price: $-66.45
# day 1207 to 1208 | predicted trend: 1 | target trend: 1 | predicted price: $116.90 | actual price: $184.32
# difference from predicted price to actual price: $-67.42
# day 1208 to 1209 | predicted trend: 1 | target trend: 1 | predicted price: $117.16 | actual price: $182.96
# difference from predicted price to actual price: $-65.80
# day 1209 to 1210 | predicted trend: 0 | target trend: 1 | predicted price: $118.49 | actual price: $184.83
# difference from predicted price to actual price: $-66.34
# day 1210 to 1211 | predicted trend: 0 | target trend: 0 | predicted price: $118.01 | actual price: $185.62
# difference from predicted price to actual price: $-67.61
# day 1211 to 1212 | predicted trend: 0 | target trend: 0 | predicted price: $114.27 | actual price: $183.87
# difference from predicted price to actual price: $-69.60
# day 1212 to 1213 | predicted trend: 0 | target trend: 1 | predicted price: $112.09 | actual price: $178.14
# difference from predicted price to actual price: $-66.05
# day 1213 to 1214 | predicted trend: 0 | target trend: 0 | predicted price: $110.99 | actual price: $179.51
# difference from predicted price to actual price: $-68.52
# day 1214 to 1215 | predicted trend: 0 | target trend: 0 | predicted price: $105.08 | actual price: $180.34
# difference from predicted price to actual price: $-75.26
# day 1215 to 1216 | predicted trend: 1 | target trend: 1 | predicted price: $98.30 | actual price: $167.69
# difference from predicted price to actual price: $-69.39
# day 1216 to 1217 | predicted trend: 1 | target trend: 1 | predicted price: $101.19 | actual price: $166.79
# difference from predicted price to actual price: $-65.60
# day 1217 to 1218 | predicted trend: 0 | target trend: 1 | predicted price: $106.33 | actual price: $173.46
# difference from predicted price to actual price: $-67.13
# day 1218 to 1219 | predicted trend: 0 | target trend: 0 | predicted price: $106.18 | actual price: $177.08
# difference from predicted price to actual price: $-70.90
# day 1219 to 1220 | predicted trend: 0 | target trend: 0 | predicted price: $103.98 | actual price: $173.77
# difference from predicted price to actual price: $-69.79
# day 1220 to 1221 | predicted trend: 1 | target trend: 1 | predicted price: $103.85 | actual price: $172.69
# difference from predicted price to actual price: $-68.84
# day 1221 to 1222 | predicted trend: 1 | target trend: 1 | predicted price: $106.63 | actual price: $173.50
# difference from predicted price to actual price: $-66.87
# day 1222 to 1223 | predicted trend: 0 | target trend: 1 | predicted price: $109.56 | actual price: $178.26
# difference from predicted price to actual price: $-68.70
# day 1223 to 1224 | predicted trend: 0 | target trend: 0 | predicted price: $109.48 | actual price: $179.36
# difference from predicted price to actual price: $-69.88
# day 1224 to 1225 | predicted trend: 0 | target trend: 0 | predicted price: $107.81 | actual price: $178.42
# difference from predicted price to actual price: $-70.61
# day 1225 to 1226 | predicted trend: 0 | target trend: 0 | predicted price: $106.60 | actual price: $176.01
# difference from predicted price to actual price: $-69.41
# day 1226 to 1227 | predicted trend: 0 | target trend: 0 | predicted price: $105.62 | actual price: $176.00
# difference from predicted price to actual price: $-70.38
# day 1227 to 1228 | predicted trend: 0 | target trend: 0 | predicted price: $104.61 | actual price: $174.05
# difference from predicted price to actual price: $-69.44
# day 1228 to 1229 | predicted trend: 1 | target trend: 0 | predicted price: $104.46 | actual price: $173.99
# difference from predicted price to actual price: $-69.53
# day 1229 to 1230 | predicted trend: 1 | target trend: 1 | predicted price: $104.79 | actual price: $174.36
# difference from predicted price to actual price: $-69.57
# day 1230 to 1231 | predicted trend: 1 | target trend: 1 | predicted price: $105.57 | actual price: $174.65
# difference from predicted price to actual price: $-69.08
# day 1231 to 1232 | predicted trend: 1 | target trend: 1 | predicted price: $105.84 | actual price: $175.92
# difference from predicted price to actual price: $-70.08
# day 1232 to 1233 | predicted trend: 1 | target trend: 1 | predicted price: $105.87 | actual price: $175.19
# difference from predicted price to actual price: $-69.32
# day 1233 to 1234 | predicted trend: 1 | target trend: 1 | predicted price: $107.28 | actual price: $175.85
# difference from predicted price to actual price: $-68.57
# day 1234 to 1235 | predicted trend: 1 | target trend: 1 | predicted price: $110.32 | actual price: $178.00
# difference from predicted price to actual price: $-67.68
# day 1235 to 1236 | predicted trend: 0 | target trend: 1 | predicted price: $113.82 | actual price: $181.93
# difference from predicted price to actual price: $-68.11
# day 1236 to 1237 | predicted trend: 0 | target trend: 0 | predicted price: $112.31 | actual price: $185.00
# difference from predicted price to actual price: $-72.69
# day 1237 to 1238 | predicted trend: 1 | target trend: 1 | predicted price: $112.02 | actual price: $184.95
# difference from predicted price to actual price: $-72.93
# day 1238 to 1239 | predicted trend: 1 | target trend: 1 | predicted price: $112.15 | actual price: $185.57
# difference from predicted price to actual price: $-73.42
# day 1239 to 1240 | predicted trend: 1 | target trend: 1 | predicted price: $113.01 | actual price: $185.21
# difference from predicted price to actual price: $-72.20
# day 1240 to 1241 | predicted trend: 1 | target trend: 1 | predicted price: $114.95 | actual price: $187.29
# difference from predicted price to actual price: $-72.34
# day 1241 to 1242 | predicted trend: 1 | target trend: 1 | predicted price: $119.27 | actual price: $189.09
# difference from predicted price to actual price: $-69.82
# day 1242 to 1243 | predicted trend: 1 | target trend: 1 | predicted price: $121.73 | actual price: $195.92
# difference from predicted price to actual price: $-74.19
# day 1243 to 1244 | predicted trend: 1 | target trend: 1 | predicted price: $121.88 | actual price: $194.01
# difference from predicted price to actual price: $-72.14
# day 1244 to 1245 | predicted trend: 1 | target trend: 1 | predicted price: $122.99 | actual price: $196.21
# difference from predicted price to actual price: $-73.22
# day 1245 to 1246 | predicted trend: 1 | target trend: 1 | predicted price: $123.24 | actual price: $196.24
# difference from predicted price to actual price: $-73.00
# day 1246 to 1247 | predicted trend: 0 | target trend: 1 | predicted price: $126.27 | actual price: $195.70
# difference from predicted price to actual price: $-69.43
# day 1247 to 1248 | predicted trend: 0 | target trend: 0 | predicted price: $123.21 | actual price: $202.29
# difference from predicted price to actual price: $-79.08
# day 1248 to 1249 | predicted trend: 0 | target trend: 0 | predicted price: $121.10 | actual price: $201.82
# difference from predicted price to actual price: $-80.72
# day 1249 to 1250 | predicted trend: 0 | target trend: 1 | predicted price: $119.44 | actual price: $198.08
# difference from predicted price to actual price: $-78.64
# day 1250 to 1251 | predicted trend: 0 | target trend: 0 | predicted price: $118.43 | actual price: $198.50
# difference from predicted price to actual price: $-80.07
# day 1251 to 1252 | predicted trend: 0 | target trend: 0 | predicted price: $117.80 | actual price: $200.11
# difference from predicted price to actual price: $-82.31
# day 1252 to 1253 | predicted trend: 1 | target trend: 1 | predicted price: $116.31 | actual price: $197.25
# difference from predicted price to actual price: $-80.94
# day 1253 to 1254 | predicted trend: 0 | target trend: 1 | predicted price: $117.25 | actual price: $197.13
# difference from predicted price to actual price: $-79.88
# day 1254 to 1255 | predicted trend: 0 | target trend: 0 | predicted price: $117.15 | actual price: $199.12
# difference from predicted price to actual price: $-81.97
# day 1255 to 1256 | predicted trend: 0 | target trend: 0 | predicted price: $114.62 | actual price: $197.33
# difference from predicted price to actual price: $-82.71
# day 1256 to 1257 | predicted trend: 0 | target trend: 0 | predicted price: $109.25 | actual price: $194.06
# difference from predicted price to actual price: $-84.81
# day 1257 to 1258 | predicted trend: 1 | target trend: 1 | predicted price: $105.51 | actual price: $186.59
# difference from predicted price to actual price: $-81.08
# Accuracy: 81.6%
# loss: 0.2245
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-1-dc1378c1c6a2>:208: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('difference from predicted price to actual price: $%.2f ' % (current_price_prediction[i] - raw_open_price_data[i]))
